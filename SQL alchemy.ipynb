# %%
# !pip install sqlalchemy

# %%
# !pip install pandas

# %%
# !pip install pyodbc

# %%
from sqlalchemy import create_engine

engine = create_engine('mssql+pyodbc://@DESKTOP-H3GSE4S/Project_Data?driver=ODBC+Driver+17+for+SQL+Server')

connection = engine.connect()
# Out:
# ---------------------------------------------------------------------------
# Error                                     Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/sqlalchemy/engine/base.py in __init__(self, engine, connection, _has_events, _allow_revalidate, _allow_autobegin)
#     145             try:
# --> 146                 self._dbapi_connection = engine.raw_connection()
#     147             except dialect.loaded_dbapi.Error as err:
#
# /usr/local/lib/python3.10/dist-packages/sqlalchemy/engine/base.py in raw_connection(self)
#    3301         """
# -> 3302         return self.pool.connect()
#    3303
#
# /usr/local/lib/python3.10/dist-packages/sqlalchemy/pool/base.py in connect(self)
#     448         """
# --> 449         return _ConnectionFairy._checkout(self)
#     450
#
# /usr/local/lib/python3.10/dist-packages/sqlalchemy/pool/base.py in _checkout(cls, pool, threadconns, fairy)
#    1262         if not fairy:
# ...

# %%
try:
    # Example query to fetch data from a table
    query = "SELECT * FROM Customers"  # Replace with your actual table name
    result = connection.execute(query)

    # Print the results
    for row in result:
        print(row)
except Exception as e:
    print(f"Error: {e}")
finally:
    connection.close()  # Close the connection after the operation
# Out:
# Error: name 'connection' is not defined
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-13fe13450975> in <cell line: 1>()
#      10     print(f"Error: {e}")
#      11 finally:
# ---> 12     connection.close()  # Close the connection after the operation
#
# NameError: name 'connection' is not defined

# %%
import pyodbc

# List available ODBC drivers
drivers = [driver for driver in pyodbc.drivers()]
print(drivers)
# Out:
# []
